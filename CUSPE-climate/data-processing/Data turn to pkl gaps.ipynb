# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('carbon-data-gaps-202207.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7528/256438263.py in <module>
# ----> 1 test = pd.read_csv('carbon-data-gaps-202207.csv')
#
# ~\Anaconda3\Lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data = []

with open('carbon-data-gaps-202207.txt','r') as file:
    for line in file:
        splitline = []
        for point in line.split('\t'):
            splitline.append(point)
        data.append(splitline)

# %%
data_array = np.zeros((len(data),len(data[0])))
data_array = data_array.astype(dtype=object)
print(data_array.shape)
# Out:
# (23, 10)

# %%
for i, line in enumerate(data):
    for j, point in enumerate(line):
        print(line[j], i,j)
        try: 
            data_array[i,j] = line[j]
        except UnicodeEncodeError:
            continue
# Out:
# Area 0 0
# Activity 0 1
# Current Accuracy / Confidence level in data 0 2
# Current Methodology / Data source 0 3
# Reason for exclusion to date 0 4
# Who holds this data now 0 5
# What is needed to improve this data 0 6
# Emissions Scope 0 7
# Likely carbon impact (size of the problem) 0 8
# Sarah's notes July 2022
#  0 9
# Buildings and utilities 1 0
# Refrigerant gases leakage from air conditioning units in CCC-controlled buildings 1 1
# Medium 1 2
# "Estimated based on last year’s data, which was based on leakage assumed from top-ups at servicing, applied to CCC list of A/C units, type of refrigerant gas and capacity. " 1 3
# N/A 1 4
# CCC's maintenance contractor or the Property team 1 5
# Use actual data from AC servicing reports. This data should already exist but I have had difficulty getting hold of it.  1 6
# 1 1 7
# Very low 1 8
# we now have this data for 2021-22
#  1 9
# Transport 2 0
# Social and education transport in own fleet.  2 1
# Medium 2 2
# ...

# %%
data_array
# Out:
# array([['Area', 'Activity',
#         'Current Accuracy / Confidence level in data',
#         'Current Methodology / Data source',
#         'Reason for exclusion to date', 'Who holds this data now',
#         'What is needed to improve this data', 'Emissions Scope',
#         'Likely carbon impact (size of the problem)',
#         "Sarah's notes July 2022\n"],
#        ['Buildings and utilities',
#         'Refrigerant gases leakage from air conditioning units in CCC-controlled buildings',
#         'Medium',
#         '"Estimated based on last year’s data, which was based on leakage assumed from top-ups at servicing, applied to CCC list of A/C units, type of refrigerant gas and capacity. "',
#         'N/A', "CCC's maintenance contractor or the Property team",
#         'Use actual data from AC servicing reports. This data should already exist but I have had difficulty getting hold of it. ',
#         '1', 'Very low', 'we now have this data for 2021-22\n'],
# ...

# %%
#data_array[0,:]
for i, point in  enumerate(data_array[:,-1]):
    data_array[i,-1] = point[:-1]
data_array
# Out:
# array([['Area', 'Activity',
#         'Current Accuracy / Confidence level in data',
#         'Current Methodology / Data source',
#         'Reason for exclusion to date', 'Who holds this data now',
#         'What is needed to improve this data', 'Emissions Scope',
#         'Likely carbon impact (size of the problem)',
#         "Sarah's notes July 202"],
#        ['Buildings and utilities',
#         'Refrigerant gases leakage from air conditioning units in CCC-controlled buildings',
#         'Medium',
#         '"Estimated based on last year’s data, which was based on leakage assumed from top-ups at servicing, applied to CCC list of A/C units, type of refrigerant gas and capacity. "',
#         'N/A', "CCC's maintenance contractor or the Property team",
#         'Use actual data from AC servicing reports. This data should already exist but I have had difficulty getting hold of it. ',
#         '1', 'Very low', 'we now have this data for 2021-2'],
# ...

# %%
df = pd.DataFrame(data_array[1:,:].T, index=data_array[0])

# %%
data[0][-1] = data[0][-1][:-1]

# %%
data[0][-1]
# Out:
# "Sarah's notes July 2022"

# %%
df
# Out:
#                                                                                             0   \
# Area                                                                   Buildings and utilities
# Activity                                     Refrigerant gases leakage from air conditionin...
# Current Accuracy / Confidence level in data                                             Medium
# Current Methodology / Data source            "Estimated based on last year’s data, which wa...
# Reason for exclusion to date                                                               N/A
# Who holds this data now                      CCC's maintenance contractor or the Property team
# What is needed to improve this data          Use actual data from AC servicing reports. Thi...
# Emissions Scope                                                                              1
# Likely carbon impact (size of the problem)                                            Very low
# ...

# %%
df.to_pickle('carbon-data-gaps-202207.pkl')

# %%
test = pd.read_pickle('carbon-data-gaps-202207.pkl')

# %%
test
# Out:
#                                                                                             0   \
# Area                                                                   Buildings and utilities
# Activity                                     Refrigerant gases leakage from air conditionin...
# Current Accuracy / Confidence level in data                                             Medium
# Current Methodology / Data source            "Estimated based on last year’s data, which wa...
# Reason for exclusion to date                                                               N/A
# Who holds this data now                      CCC's maintenance contractor or the Property team
# What is needed to improve this data          Use actual data from AC servicing reports. Thi...
# Emissions Scope                                                                              1
# Likely carbon impact (size of the problem)                                            Very low
# ...
