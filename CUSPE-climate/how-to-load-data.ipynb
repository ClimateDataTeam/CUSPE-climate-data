# %% [markdown]
# ## Data from the council is stored in Pandas dataframes, in .pkl (pickle) files
#
# - pandas stores indexed data sets

# %% [markdown]
# ### 1. Let's import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### 2. Load and then showcase the Climate Summary (net or gross) Data
#
# The net data has all of the gross data as well

# %%
net_summary = pd.read_pickle('./data/net-summary.pkl')
net_summary
# Out:
#                                                                        0   \
# Category                                            Buildings & utilities
# Scope 1                                                       1253.844035
# Scope 2                                                       4387.972003
# Scope 3                                                       1245.545303
# "Carbon footprint 2020-21 (tonnes CO2e) (scopes...            6887.361342
# Additional outside of scopes                                            0
#
#                                                              1            2   \
# Category                                              Transport        Waste
# Scope 1                                              590.499016          0.0
# Scope 2                                                     0.0          0.0
# Scope 3                                             3446.284029  39320.32708
# ...

# %% [markdown]
# Can compare it to the gross total

# %%
gross_summary = pd.read_pickle('./data/gross-summary.pkl')
gross_summary
# Out:
#                                                                         0  \
# Category                                            Buildings & utilities
# Scope 1                                                            1254.0
# Scope 2                                                            4388.0
# Scope 3                                                            1246.0
# " Carbon footprint 2020-21 (tonnes CO2e) (scope...                 6887.0
# Additional outside of scopes                                            0
#
#                                                             1        2  \
# Category                                            Transport    Waste
# Scope 1                                                 590.0        0
# Scope 2                                                     0        0
# Scope 3                                                3446.0  39320.0
# " Carbon footprint 2020-21 (tonnes CO2e) (scope...     4037.0  39320.0
# ...

# %% [markdown]
# ### 2. Load and then showcase the Climate Footprint Data

# %%
climate_report = pd.read_pickle('./data/climate-report-summary-202207.pkl')
climate_report
# Out:
#                                                                                  0   \
# Scope                                                                             1
# Category                                                      Buildings & utilities
# Sub-category                                                                    Gas
# Activity / aspect                                                   Gas - CCC sites
# Data                                                Gas purchased for CCC buildings
#  2020-21 Value                                                            6357552.0
# Unit                                                                 kWh (Gross CV)
# 2020 Carbon conversion factor (to convert to kg...                          0.18387
#  Gross Carbon Footprint (tonnes CO2e)                                       1168.96
# Data source                                                             Energy data
# ...

# %% [markdown]
# ### 4. Load and then showcase the Carbon Data Gaps

# %%
carbon_gaps = pd.read_pickle('./data/carbon-data-gaps-202207.pkl')
carbon_gaps
# Out:
#                                                                                             0   \
# Area                                                                   Buildings and utilities
# Activity                                     Refrigerant gases leakage from air conditionin...
# Current Accuracy / Confidence level in data                                             Medium
# Current Methodology / Data source            "Estimated based on last year’s data, which wa...
# Reason for exclusion to date                                                               N/A
# Who holds this data now                      CCC's maintenance contractor or the Property team
# What is needed to improve this data          Use actual data from AC servicing reports. Thi...
# Emissions Scope                                                                              1
# Likely carbon impact (size of the problem)                                            Very low
# ...
